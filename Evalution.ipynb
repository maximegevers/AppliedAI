# %% [markdown]
# <a href="https://colab.research.google.com/github/maximegevers/AppliedAI/blob/main/Evalution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
preds = [2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 1,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 1,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 1,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 1,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 1,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 0,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 2,
 0,
 1,
 0,
 3,
 3,
 2,
 0,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2]

actuals = [2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2,
 2,
 1,
 3,
 0,
 1,
 0,
 3,
 2,
 3,
 2,
 0,
 1,
 2,
 2,
 3,
 1,
 3,
 0,
 0,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 0,
 0,
 2,
 2,
 1,
 1,
 0,
 3,
 1,
 2,
 3,
 0,
 0,
 1,
 0,
 3,
 3,
 2,
 1,
 1,
 3,
 0,
 2,
 3,
 3,
 2,
 3,
 1,
 1,
 1,
 1,
 2,
 1,
 2,
 3,
 0,
 0,
 2]

labels=['cloth', 'ffp2', 'surgical', 'without_mask']

 # Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from matplotlib import pyplot as plt
cm = confusion_matrix(actuals, preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
# disp.plot()
# plt.subplot(figsize=(100, 100))
plt.show()
# Accuracy
#from sklearn.metrics import accuracy_score
#accuracy_score(actuals, preds)
# Recall
#from sklearn.metrics import recall_score
#recall_score(actuals, preds, average=None)
# Precision
#from sklearn.metrics import precision_score
#precision_score(actuals, preds, average=None)
